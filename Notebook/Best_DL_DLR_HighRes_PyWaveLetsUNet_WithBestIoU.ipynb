%%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

image_dir = '/content/dataset/images'  # Path to your images folder
output_dir = '/content/dataset/transformed_images'  # Where to save the transformed components
os.makedirs(output_dir, exist_ok=True)

num=40

image_files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])[:num]

# %%
# %mv dataset/temp/Lung\ Segmentation/masks/* dataset/masks/
MASK_PATH = '/content/dataset/masks/'
MASK_PATH = '/content/dataset/masks/'
TEST_PATH = '/content/dataset/test/'

# %%
# importing os module
import os

# suffix cropping function
def rchop(s, suffix):
    if suffix and s.endswith(suffix):
        return s[:-len(suffix)]
    return s

suffix = "_mask.png"

# iterate over all mask images and edit the file-names
for count, filename in enumerate(os.listdir("/content/dataset/masks")):
  src = "/content/dataset/masks/" + filename
  res = rchop(src, suffix)
  dst = ""
  if src != res:
    dst = rchop(src, suffix) + ".png"
    os.rename(src, dst)

# %%
# check the number of files in the images/ and masks/ directories
import os.path

print("number of files in images/ directory: " + str(len([name for name in os.listdir("/content/dataset/images/")])))
print("number of files in masks/ directory: " + str(len([name for name in os.listdir("/content/dataset/masks/")])))
# Out:
# number of files in images/ directory: 800
# number of files in masks/ directory: 704

# %%
# function to confirm the existence of a file in a given directory
def searchFile(fileName, TARGET_PATH):
  for root, dirs, files in os.walk(TARGET_PATH):
    for Files in files:
      #print(Files)
      found = Files.find(fileName)
      if found != -1:
        break
  return found

# %%
# %mkdir /content/dataset/orphan_images

# %%
# clean up the images/ directory by removing all images that do not have a mask
import shutil

cnt = 0

for count, filename in enumerate(os.listdir("/content/dataset/images")):
  found = searchFile(filename, MASK_PATH)
  if found == -1:
    cnt = cnt + 1
    src = "/content/dataset/images/" + filename
    dst = "/content/dataset/orphan_images/" + filename
    dest = shutil.move(src, dst)
print("number of files not matched: " + str(cnt))
# Out:
# number of files not matched: 96

# %%
# confirm consistency
print("number of files in images/ directory: " + str(len([name for name in os.listdir("/content/dataset/images/")])))
print("number of files in masks/ directory: " + str(len([name for name in os.listdir("/content/dataset/masks/")])))
# Out:
# number of files in images/ directory: 704
# number of files in masks/ directory: 704

# %% [markdown]
# Make proper accurate splits of data

# %%
import os
import shutil
import random

# Assuming the previous code has already been executed, and the following directories are set up:
IMAGE_PATH = '/content/dataset/images/'
MASK_PATH = '/content/dataset/masks/'
TEST_PATH = '/content/dataset/test/'

# Create the test directory if it doesn't exist
os.makedirs(TEST_PATH, exist_ok=True)

# Get all image filenames
all_images = sorted([f for f in os.listdir(IMAGE_PATH) if f.endswith('.png')])

# Calculate 10% for the test split
num_test = int(len(all_images) * 0.1)

# Randomly select 10% of the dataset for testing
test_indices = random.sample(range(len(all_images)), num_test)

# Move selected images to the test directory
for idx in test_indices:
    src = os.path.join(IMAGE_PATH, all_images[idx])
    dst = os.path.join(TEST_PATH, all_images[idx])
    shutil.move(src, dst)

print(f"Moved {num_test} images to the test directory: {TEST_PATH}")

# Check the number of files in the test directory
print("Number of files in the test directory: " + str(len(os.listdir(TEST_PATH))))
# Out:
# Moved 70 images to the test directory: /content/dataset/test/
# Number of files in the test directory: 70

# %%
# Create the test_masks directory if it doesn't exist
TEST_MASKS_PATH = '/content/dataset/test_masks/'
os.makedirs(TEST_MASKS_PATH, exist_ok=True)

# Move corresponding masks to the test_masks directory
for idx in test_indices:
    # Get the filename of the image that was moved
    image_filename = all_images[idx]

    # The mask filename is the same as the image filename
    mask_filename = image_filename  # No changes needed to the filename
    src_mask = os.path.join(MASK_PATH, mask_filename)

    # Print debug information
    print(f"Checking for mask: {mask_filename}")
    print(f"Source mask path: {src_mask}")

    # Check if the corresponding mask exists before moving
    if os.path.exists(src_mask):
        dst_mask = os.path.join(TEST_MASKS_PATH, mask_filename)
        shutil.move(src_mask, dst_mask)
    else:
        print(f"Mask not found for image: {image_filename}")

# Check the number of files in the test_masks directory
print("Number of masks in the test_masks directory: " + str(len(os.listdir(TEST_MASKS_PATH))))
# Out:
# Checking for mask: CHNCXR_0140_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0140_0.png
# Checking for mask: CHNCXR_0420_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0420_1.png
# Checking for mask: MCUCXR_0017_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0017_0.png
# Checking for mask: CHNCXR_0249_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0249_0.png
# Checking for mask: MCUCXR_0282_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0282_1.png
# Checking for mask: CHNCXR_0155_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0155_0.png
# Checking for mask: CHNCXR_0586_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0586_1.png
# Checking for mask: CHNCXR_0471_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0471_1.png
# Checking for mask: MCUCXR_0057_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0057_0.png
# Checking for mask: CHNCXR_0315_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0315_0.png
# Checking for mask: CHNCXR_0608_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0608_1.png
# Checking for mask: MCUCXR_0090_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0090_0.png
# Checking for mask: CHNCXR_0268_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0268_0.png
# Checking for mask: MCUCXR_0126_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0126_1.png
# Checking for mask: MCUCXR_0275_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0275_1.png
# Checking for mask: CHNCXR_0063_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0063_0.png
# Checking for mask: CHNCXR_0543_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0543_1.png
# Checking for mask: MCUCXR_0063_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0063_0.png
# Checking for mask: MCUCXR_0141_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0141_1.png
# Checking for mask: CHNCXR_0307_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0307_0.png
# Checking for mask: MCUCXR_0251_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0251_1.png
# Checking for mask: CHNCXR_0046_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0046_0.png
# Checking for mask: CHNCXR_0397_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0397_1.png
# Checking for mask: CHNCXR_0658_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0658_1.png
# Checking for mask: CHNCXR_0092_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0092_0.png
# Checking for mask: CHNCXR_0651_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0651_1.png
# Checking for mask: MCUCXR_0188_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0188_1.png
# Checking for mask: CHNCXR_0029_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0029_0.png
# Checking for mask: CHNCXR_0610_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0610_1.png
# Checking for mask: CHNCXR_0142_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0142_0.png
# Checking for mask: MCUCXR_0099_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0099_0.png
# Checking for mask: CHNCXR_0269_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0269_0.png
# Checking for mask: CHNCXR_0320_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0320_0.png
# Checking for mask: CHNCXR_0598_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0598_1.png
# Checking for mask: MCUCXR_0092_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0092_0.png
# Checking for mask: CHNCXR_0123_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0123_0.png
# Checking for mask: CHNCXR_0557_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0557_1.png
# Checking for mask: CHNCXR_0311_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0311_0.png
# Checking for mask: CHNCXR_0650_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0650_1.png
# Checking for mask: CHNCXR_0459_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0459_1.png
# Checking for mask: CHNCXR_0646_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0646_1.png
# Checking for mask: MCUCXR_0068_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0068_0.png
# Checking for mask: CHNCXR_0606_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0606_1.png
# Checking for mask: CHNCXR_0537_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0537_1.png
# Checking for mask: CHNCXR_0577_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0577_1.png
# Checking for mask: MCUCXR_0058_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0058_0.png
# Checking for mask: CHNCXR_0094_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0094_0.png
# Checking for mask: CHNCXR_0252_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0252_0.png
# Checking for mask: CHNCXR_0072_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0072_0.png
# Checking for mask: CHNCXR_0469_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0469_1.png
# Checking for mask: MCUCXR_0331_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0331_1.png
# Checking for mask: CHNCXR_0579_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0579_1.png
# Checking for mask: CHNCXR_0480_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0480_1.png
# Checking for mask: MCUCXR_0023_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0023_0.png
# Checking for mask: CHNCXR_0068_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0068_0.png
# Checking for mask: MCUCXR_0113_1.png
# Source mask path: /content/dataset/masks/MCUCXR_0113_1.png
# Checking for mask: CHNCXR_0607_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0607_1.png
# Checking for mask: MCUCXR_0083_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0083_0.png
# Checking for mask: CHNCXR_0601_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0601_1.png
# Checking for mask: CHNCXR_0035_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0035_0.png
# Checking for mask: CHNCXR_0595_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0595_1.png
# Checking for mask: CHNCXR_0590_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0590_1.png
# Checking for mask: MCUCXR_0059_0.png
# Source mask path: /content/dataset/masks/MCUCXR_0059_0.png
# Checking for mask: CHNCXR_0594_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0594_1.png
# Checking for mask: CHNCXR_0581_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0581_1.png
# Checking for mask: CHNCXR_0618_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0618_1.png
# Checking for mask: CHNCXR_0509_1.png
# Source mask path: /content/dataset/masks/CHNCXR_0509_1.png
# Checking for mask: CHNCXR_0084_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0084_0.png
# Checking for mask: CHNCXR_0222_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0222_0.png
# Checking for mask: CHNCXR_0103_0.png
# Source mask path: /content/dataset/masks/CHNCXR_0103_0.png
# Number of masks in the test_masks directory: 70

# %%
print("Number of files in the mask directory: " + str(len(os.listdir(MASK_PATH))))
print("Number of files in the train_image directory: " + str(len(os.listdir(IMAGE_PATH))))
# Out:
# Number of files in the mask directory: 634
# Number of files in the train_image directory: 634

# %% [markdown]
# Testing PyWavelet Transformations

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt

# Generate a sample 2D array (image-like) for demonstration
data = np.random.rand(256, 256)

# Perform 2D Discrete Wavelet Transform using the Daubechies 4 (db4) wavelet
coeffs2 = pywt.dwt2(data, 'db4')

# The result of dwt2 is a tuple containing (LL, (LH, HL, HH))
LL, (LH, HL, HH) = coeffs2

# Plot the original and transformed coefficients
plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.imshow(LL, cmap='gray')
plt.title('Approximation (LL)')

plt.subplot(2, 2, 2)
plt.imshow(LH, cmap='gray')
plt.title('Horizontal Detail (LH)')

plt.subplot(2, 2, 3)
plt.imshow(HL, cmap='gray')
plt.title('Vertical Detail (HL)')

plt.subplot(2, 2, 4)
plt.imshow(HH, cmap='gray')
plt.title('Diagonal Detail (HH)')

plt.tight_layout()
plt.show()

# %%
import pywt
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# Function to load and preprocess image
def load_image(image_path):
    # Load the image in grayscale mode
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    img = cv2.resize(img, (512,512))

    # Normalize the image data (optional but helps with numerical stability)
    img = img / 255.0

    return img

# Function to perform 2D wavelet transform and plot components
def perform_wavelet_transform(image):
    # Perform 2D Discrete Wavelet Transform using the Daubechies 4 (db4) wavelet
    coeffs2 = pywt.dwt2(image, 'db4')

    # The result of dwt2 is a tuple containing (LL, (LH, HL, HH))
    LL, (LH, HL, HH) = coeffs2

    # Plot the original and transformed coefficients
    plt.figure(figsize=(10, 10))

    plt.subplot(2, 2, 1)
    plt.imshow(LL, cmap='gray')
    plt.title('Approximation (LL)')

    plt.subplot(2, 2, 2)
    plt.imshow(LH, cmap='gray')
    plt.title('Horizontal Detail (LH)')

    plt.subplot(2, 2, 3)
    plt.imshow(HL, cmap='gray')
    plt.title('Vertical Detail (HL)')

    plt.subplot(2, 2, 4)
    plt.imshow(HH, cmap='gray')
    plt.title('Diagonal Detail (HH)')

    plt.tight_layout()
    plt.show()

image_path = '/content/dataset/images/CHNCXR_0001_0.png'

image = load_image(image_path)

perform_wavelet_transform(image)

# %%
# Test images in our dataset
image_path = '/content/dataset/images/CHNCXR_0003_0.png'

# Load the image
image = load_image(image_path)

# Perform wavelet transform and plot the components
perform_wavelet_transform(image)

# %% [markdown]
# **Data Generator:**

# %%
import os
import numpy as np
import pywt
import cv2
import tensorflow as tf

class WaveletDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_folder, mask_folder, file_list, batch_size, image_size=(512,512), wavelet='db4'):
        self.image_folder = image_folder
        self.mask_folder = mask_folder
        self.file_list = file_list
        self.batch_size = batch_size
        self.image_size = image_size
        self.wavelet = wavelet

    def __len__(self):
        return int(np.ceil(len(self.file_list) / self.batch_size))

    def __getitem__(self, index):
        batch_files = self.file_list[index * self.batch_size:(index + 1) * self.batch_size]

        images = np.zeros((len(batch_files), self.image_size[0], self.image_size[1], 4))
        masks = np.zeros((len(batch_files), self.image_size[0], self.image_size[1], 1))

        for i, filename in enumerate(batch_files):
            img_path = os.path.join(self.image_folder, filename)
            mask_path = os.path.join(self.mask_folder, filename)

            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                raise ValueError(f"Error loading image from {img_path}")
            img = cv2.resize(img, self.image_size) / 255.0

            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            if mask is None:
                raise ValueError(f"Error loading mask from {mask_path}")
            mask = cv2.resize(mask, self.image_size) / 255.0
            mask = np.expand_dims(mask, axis=-1)

            coeffs2 = pywt.dwt2(img, self.wavelet)
            LL, (LH, HL, HH) = coeffs2

            wavelet_image = np.stack([LL, LH, HL, HH], axis=-1)
            wavelet_image = cv2.resize(wavelet_image, self.image_size)

            images[i] = wavelet_image
            masks[i] = mask

        return images, masks

# %% [markdown]
# **UNET MODEL:**

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

def conv_block(input_tensor, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(input_tensor, num_filters):
    x = conv_block(input_tensor, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(input_tensor, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input_tensor)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model

# Modify input shape to (512,512, 4) for wavelet-transformed images
model = build_unet((512,512,4))

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Print the model summary to confirm the architecture
model.summary()
batch_size=4
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 512, 512, 4)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 512, 512, 64)   │          2,368 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 512, 512, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512, 512, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 512, 512, 64)   │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 512, 512, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 512, 512, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 256, 256, 64)   │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 256, 256, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 256, 256, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256, 256, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 256, 256, 128)  │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 256, 256, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 256, 256, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 128, 128, 128)  │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 128, 128, 256)  │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 128, 128, 256)  │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 128, 128, 256)  │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 128, 128, 256)  │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 128, 128, 256)  │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 128, 128, 256)  │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 64, 64, 256)    │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 64, 64, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 512)    │      2,359,808 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 64, 64, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 64, 64, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 32, 32, 512)    │              0 │ activation_7[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 32, 32, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 1024)   │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 32, 32, 1024)   │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 32, 32, 1024)   │      9,438,208 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 32, 32, 1024)   │          4,096 │ conv2d_9[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 32, 32, 1024)   │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 64, 64, 512)    │      2,097,664 │ activation_9[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 64, 64, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ activation_7[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 64, 64, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 64, 64, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 64, 64, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 64, 64, 512)    │      2,359,808 │ activation_10[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 64, 64, 512)    │          2,048 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 64, 64, 512)    │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 128, 128, 256)  │        524,544 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 128, 128, 512)  │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 128, 128, 256)  │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 128, 128, 256)  │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 128, 128, 256)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 128, 128, 256)  │        590,080 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 128, 128, 256)  │          1,024 │ conv2d_13[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 128, 128, 256)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 256, 256, 128)  │        131,200 │ activation_13[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 256, 256, 256)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 256, 256, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 256, 256, 128)  │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 256, 256, 128)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 256, 256, 128)  │        147,584 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 256, 256, 128)  │            512 │ conv2d_15[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 256, 256, 128)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 512, 512, 64)   │         32,832 │ activation_15[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 512, 512, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 512, 512, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 512, 512, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 512, 512, 64)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 512, 512, 64)   │         36,928 │ activation_16[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 512, 512, 64)   │            256 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_17             │ (None, 512, 512, 64)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 512, 512, 1)    │             65 │ activation_17[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,055,873 (118.47 MB)
#  Trainable params: 31,044,097 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %% [markdown]
# **TRAINING THE MODEL:**

# %%
from tensorflow.keras import backend as K

def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = K.sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (K.sum(y_true) + K.sum(y_pred) + smooth)

model.compile(optimizer=optimizer, loss=dice_loss, metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Split data
image_files = os.listdir(IMAGE_PATH)
train_files, val_files = train_test_split(image_files, test_size=0.2, random_state=42)

train_data_gen = WaveletDataGenerator(
    image_folder=IMAGE_PATH,
    mask_folder=MASK_PATH,
    file_list=train_files,
    batch_size=batch_size
)

val_data_gen = WaveletDataGenerator(
    image_folder=IMAGE_PATH,
    mask_folder=MASK_PATH,
    file_list=val_files,
    batch_size=batch_size
)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
model_checkpoint = ModelCheckpoint("best_model.keras", monitor='val_loss', save_best_only=True)

history = model.fit(
    train_data_gen,
    validation_data=val_data_gen,
    epochs=33,
    callbacks=[early_stopping, model_checkpoint, reduce_lr],
    verbose=1
)

model.save("LHRPWU.h5")
# Out:
# Epoch 1/33
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 311s 2s/step - accuracy: 0.8760 - loss: 0.2874 - val_accuracy: 0.7464 - val_loss: 0.7787 - learning_rate: 1.0000e-04
# Epoch 2/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 183s 1s/step - accuracy: 0.9742 - loss: 0.0774 - val_accuracy: 0.7446 - val_loss: 0.9290 - learning_rate: 1.0000e-04
# Epoch 3/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9755 - loss: 0.0664 - val_accuracy: 0.8376 - val_loss: 0.3864 - learning_rate: 1.0000e-04
# Epoch 4/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9756 - loss: 0.0604 - val_accuracy: 0.9445 - val_loss: 0.1149 - learning_rate: 1.0000e-04
# Epoch 5/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9792 - loss: 0.0507 - val_accuracy: 0.9778 - val_loss: 0.0508 - learning_rate: 1.0000e-04
# Epoch 6/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9792 - loss: 0.0491 - val_accuracy: 0.9785 - val_loss: 0.0491 - learning_rate: 1.0000e-04
# Epoch 7/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9809 - loss: 0.0448 - val_accuracy: 0.9038 - val_loss: 0.2423 - learning_rate: 1.0000e-04
# Epoch 8/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 192s 1s/step - accuracy: 0.9800 - loss: 0.0441 - val_accuracy: 0.9776 - val_loss: 0.0480 - learning_rate: 1.0000e-04
# Epoch 9/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9803 - loss: 0.0424 - val_accuracy: 0.9794 - val_loss: 0.0441 - learning_rate: 1.0000e-04
# Epoch 10/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9817 - loss: 0.0397 - val_accuracy: 0.9780 - val_loss: 0.0470 - learning_rate: 1.0000e-04
# Epoch 11/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9819 - loss: 0.0387 - val_accuracy: 0.9799 - val_loss: 0.0421 - learning_rate: 1.0000e-04
# Epoch 12/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9822 - loss: 0.0369 - val_accuracy: 0.9794 - val_loss: 0.0425 - learning_rate: 1.0000e-04
# Epoch 13/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 215s 1s/step - accuracy: 0.9821 - loss: 0.0367 - val_accuracy: 0.9796 - val_loss: 0.0418 - learning_rate: 1.0000e-04
# Epoch 14/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9813 - loss: 0.0376 - val_accuracy: 0.9806 - val_loss: 0.0396 - learning_rate: 1.0000e-04
# Epoch 15/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9837 - loss: 0.0333 - val_accuracy: 0.9789 - val_loss: 0.0427 - learning_rate: 1.0000e-04
# Epoch 16/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9822 - loss: 0.0358 - val_accuracy: 0.9587 - val_loss: 0.0864 - learning_rate: 1.0000e-04
# Epoch 17/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9764 - loss: 0.0467 - val_accuracy: 0.9747 - val_loss: 0.0502 - learning_rate: 1.0000e-04
# Epoch 18/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9798 - loss: 0.0400 - val_accuracy: 0.9746 - val_loss: 0.0521 - learning_rate: 1.0000e-04
# Epoch 19/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9794 - loss: 0.0403 - val_accuracy: 0.9740 - val_loss: 0.0526 - learning_rate: 1.0000e-04
# Epoch 20/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 202s 1s/step - accuracy: 0.9814 - loss: 0.0363 - val_accuracy: 0.9802 - val_loss: 0.0397 - learning_rate: 5.0000e-05
# Epoch 21/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9824 - loss: 0.0346 - val_accuracy: 0.9812 - val_loss: 0.0376 - learning_rate: 5.0000e-05
# Epoch 22/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9826 - loss: 0.0341 - val_accuracy: 0.9807 - val_loss: 0.0385 - learning_rate: 5.0000e-05
# Epoch 23/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - accuracy: 0.9822 - loss: 0.0345 - val_accuracy: 0.9811 - val_loss: 0.0373 - learning_rate: 5.0000e-05
# Epoch 24/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9822 - loss: 0.0346 - val_accuracy: 0.9801 - val_loss: 0.0392 - learning_rate: 5.0000e-05
# Epoch 25/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9833 - loss: 0.0328 - val_accuracy: 0.9808 - val_loss: 0.0379 - learning_rate: 5.0000e-05
# Epoch 26/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9831 - loss: 0.0330 - val_accuracy: 0.9807 - val_loss: 0.0378 - learning_rate: 5.0000e-05
# Epoch 27/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 214s 1s/step - accuracy: 0.9833 - loss: 0.0322 - val_accuracy: 0.9812 - val_loss: 0.0371 - learning_rate: 5.0000e-05
# Epoch 28/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 158s 1s/step - accuracy: 0.9845 - loss: 0.0301 - val_accuracy: 0.9804 - val_loss: 0.0391 - learning_rate: 5.0000e-05
# Epoch 29/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9846 - loss: 0.0303 - val_accuracy: 0.9809 - val_loss: 0.0376 - learning_rate: 5.0000e-05
# Epoch 30/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 203s 1s/step - accuracy: 0.9840 - loss: 0.0312 - val_accuracy: 0.9809 - val_loss: 0.0373 - learning_rate: 5.0000e-05
# Epoch 31/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9856 - loss: 0.0284 - val_accuracy: 0.9808 - val_loss: 0.0378 - learning_rate: 5.0000e-05
# Epoch 32/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9843 - loss: 0.0301 - val_accuracy: 0.9808 - val_loss: 0.0377 - learning_rate: 5.0000e-05
# Epoch 33/33
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 200s 1s/step - accuracy: 0.9853 - loss: 0.0287 - val_accuracy: 0.9808 - val_loss: 0.0375 - learning_rate: 2.5000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("LatestpywavelettedUnet.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Train the model for
# Plotting training accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
# Train the model for
# Plotting training accuracy
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
#test on a few images:

# %%
import numpy as np
import cv2
import os
import pywt
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,f1_score
def load_and_preprocess_image(image_path, wavelet='db4', image_size=(512,512)):
    if not os.path.exists(image_path):
        raise ValueError(f"Image not found: {image_path}")

    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Image could not be loaded: {image_path}")

    img_resized = cv2.resize(img, image_size) / 255.0

    coeffs2 = pywt.dwt2(img_resized, wavelet)

    if coeffs2 is None or len(coeffs2) != 2:
        raise ValueError("Wavelet transformation failed to produce coefficients.")

    LL, (LH, HL, HH) = coeffs2

    LL = cv2.resize(LL, image_size)
    LH = cv2.resize(LH, image_size)
    HL = cv2.resize(HL, image_size)
    HH = cv2.resize(HH, image_size)

    wavelet_image = np.stack([LL, LH, HL, HH], axis=-1)

    return img_resized, wavelet_image


# Load and preprocess the image
image_path = "/content/dataset/images/CHNCXR_0007_0.png"  # Replace with your actual image path
mask_path = "/content/dataset/masks/CHNCXR_0007_0.png" # Replace with your actual mask path



def load_ground_truth_mask(mask_path, image_size=(512, 512)):
    if not os.path.exists(mask_path):
        raise ValueError(f"Ground truth mask not found: {mask_path}")

    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Ground truth mask could not be loaded: {mask_path}")

    mask_resized = cv2.resize(mask, image_size)
    # Ensure the mask is binary
    mask_binary = (mask_resized > 127).astype(np.uint8)
    return mask_binary

original_image, preprocessed_image = load_and_preprocess_image(image_path)
ground_truth_mask = load_ground_truth_mask(mask_path)

# Add a batch dimension for model prediction
preprocessed_image_batch = np.expand_dims(preprocessed_image, axis=0)

print(f"Preprocessed image shape: {preprocessed_image_batch.shape}")

# Make prediction
predicted_mask = model.predict(preprocessed_image_batch)

# Ensure the predicted mask is binary
predicted_mask_binary = (predicted_mask > 0.5).astype(np.uint8)

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].imshow(original_image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

axes[1].imshow(ground_truth_mask, cmap='gray')
axes[1].set_title('Ground Truth Mask')
axes[1].axis('off')

axes[2].imshow(predicted_mask_binary[0, :, :, 0], cmap='gray')
axes[2].set_title('Predicted Mask')
axes[2].axis('off')

plt.tight_layout()
plt.show()

# Calculate and print metrics
predicted_flat = predicted_mask_binary[0, :, :, 0].flatten()
ground_truth_flat = ground_truth_mask.flatten()

accuracy = accuracy_score(ground_truth_flat, predicted_flat)
f1 = f1_score(ground_truth_flat, predicted_flat)

print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Preprocessed image shape: (1, 512, 512, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# Accuracy: 0.9086
# F1 Score: 0.8526

# %% [markdown]
# **MODEL Metrics**

# %%
from sklearn.metrics import jaccard_score, f1_score

def compute_metrics(model, data_gen):
    y_true = []
    y_pred = []

    for i in range(len(data_gen)):
        images, masks = data_gen[i]
        preds = model.predict(images)
        preds = (preds > 0.5).astype(np.uint8)  # Threshold predictions

        # Flatten and convert masks to binary if they aren't already
        y_true.append((masks > 0.5).astype(np.uint8).flatten())  # Ensure y_true is binary
        y_pred.append(preds.flatten())

    # Convert lists to arrays
    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)

    # Calculate IoU
    iou = jaccard_score(y_true, y_pred, average='binary')

    # Calculate Dice Coefficient
    dice = f1_score(y_true, y_pred)

    return iou, dice

iou, dice = compute_metrics(model, val_data_gen)
print("Val IoU:", iou)
print("Val Dice Coefficient:", dice)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# Val IoU: 0.9304473083915193
# Val Dice Coefficient: 0.9639706863242835

# %%
import os
import numpy as np
from sklearn.metrics import jaccard_score, f1_score
import cv2
import pywt

class TestWaveletDataGenerator:
    def __init__(self, image_folder, mask_folder, image_size=(512, 512), wavelet='db4'):
        self.image_paths = sorted([os.path.join(image_folder, f) for f in os.listdir(image_folder)])
        self.mask_paths = sorted([os.path.join(mask_folder, f) for f in os.listdir(mask_folder)])
        self.image_size = image_size
        self.wavelet = wavelet

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, index):
        img_path = self.image_paths[index]
        mask_path = self.mask_paths[index]

        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, self.image_size) / 255.0

        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, self.image_size) / 255.0
        mask = np.expand_dims(mask, axis=-1)

        coeffs2 = pywt.dwt2(img, self.wavelet)
        LL, (LH, HL, HH) = coeffs2

        wavelet_image = np.stack([LL, LH, HL, HH], axis=-1)
        wavelet_image = cv2.resize(wavelet_image, self.image_size)

        return np.expand_dims(wavelet_image, axis=0), np.expand_dims(mask, axis=0)


# Usage
TEST_IMAGE_PATH = "/content/dataset/test"
TEST_MASK_PATH = "/content/dataset/test_masks"

test_data_gen = TestWaveletDataGenerator(TEST_IMAGE_PATH, TEST_MASK_PATH)

# %%
def compute_metrics(model, data_gen):
    y_true = []
    y_pred = []

    for i in range(len(data_gen)):
        images, masks = data_gen[i]
        preds = model.predict(images)
        preds = (preds > 0.5).astype(np.uint8)  # Threshold predictions

        # Flatten and convert masks to binary if they aren't already
        y_true.append((masks > 0.5).astype(np.uint8).flatten())  # Ensure y_true is binary
        y_pred.append(preds.flatten())

    # Convert lists to arrays
    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)

    # Calculate IoU
    iou = jaccard_score(y_true, y_pred, average='binary')

    # Calculate Dice Coefficient
    dice = f1_score(y_true, y_pred)

    return iou, dice

iou, dice = compute_metrics(model, test_data_gen)
print("Test IoU:", iou)
print("Test Dice Coefficient:", dice)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Test IoU: 0.9428115250796122
# Test Dice Coefficient: 0.9705640644076144

# %%
#save model:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save('/content/drive/MyDrive/BestHRPWUnet.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# proper Computation of scores of IoU and dice coeffecients:

# %%
from sklearn.metrics import jaccard_score, f1_score

def compute_metrics(model, data_gen):
    y_true = []
    y_pred = []

    for i in range(len(data_gen)):
        images, masks = data_gen[i]
        preds = model.predict(images)
        preds = (preds > 0.5).astype(np.uint8)  # Threshold predictions

        # Flatten and convert masks to binary if they aren't already
        y_true.append((masks > 0.5).astype(np.uint8).flatten())  # Ensure y_true is binary
        y_pred.append(preds.flatten())

    # Convert lists to arrays
    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)

    # Calculate IoU
    iou = jaccard_score(y_true, y_pred, average='binary')

    # Calculate Dice Coefficient
    dice = f1_score(y_true, y_pred)

    return iou, dice

iou, dice = compute_metrics(model,  test_data_gen)
print("IoU:", iou)
print("Dice Coefficient:", dice)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# IoU: 0.9428115250796122
# Dice Coefficient: 0.9705640644076144

# %%
def compute_metrics(model, data_gen, batch_size=8):
    iou_scores = []
    dice_scores = []

    for i in range(len(data_gen)):
        print(f"Processing image {i+1}/{len(data_gen)}")

        image, mask = data_gen[i]
        pred = model.predict(image)
        pred = (pred > 0.5).astype(np.uint8)
        mask = (mask > 0.5).astype(np.uint8)

        iou = jaccard_score(mask.flatten(), pred.flatten())
        dice = f1_score(mask.flatten(), pred.flatten())

        iou_scores.append(iou)
        dice_scores.append(dice)

    return np.mean(iou_scores), np.mean(dice_scores)

TEST_IMAGE_PATH = "/content/dataset/test"
TEST_MASK_PATH = "/content/dataset/test_masks"

test_data_gen = TestWaveletDataGenerator(TEST_IMAGE_PATH, TEST_MASK_PATH)
iou, dice = compute_metrics(model, test_data_gen)

print("Test IoU:", iou)
print("Test Dice Coefficient:", dice)
# Out:
# Processing image 1/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 2/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 3/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 4/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 5/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 6/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 7/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 8/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 9/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 10/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 11/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 12/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Processing image 13/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 14/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 15/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 16/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 17/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Processing image 18/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 19/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Processing image 20/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Processing image 21/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Processing image 22/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 23/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 24/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 25/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 26/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 27/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 28/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 29/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Processing image 30/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 31/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Processing image 32/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Processing image 33/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Processing image 34/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Processing image 35/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Processing image 36/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 37/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 38/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 39/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 40/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 41/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 42/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 43/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Processing image 44/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Processing image 45/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 46/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Processing image 47/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 48/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Processing image 49/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 50/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 51/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 52/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 53/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Processing image 54/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 55/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 56/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 57/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 58/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 59/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 60/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Processing image 61/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Processing image 62/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 63/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 64/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Processing image 65/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Processing image 66/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Processing image 67/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Processing image 68/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Processing image 69/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Processing image 70/70
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#
jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1661).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (232).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2459).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2996).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2401).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2328).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1871).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1329).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1193).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2306).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2156).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (843).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2648).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (838).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1994).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (736).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (222).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1364).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2871).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1126).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1670).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1065).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1374).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (231).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2496).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2583).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (789).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2193).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2917).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (474).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2043).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1171).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2894).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2185).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1181).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (563).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2072).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (927).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2126).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (839).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (740).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2036).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1999).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1008).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (131).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1482).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1676).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2146).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1723).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2157).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2407).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2168).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1037).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1165).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2388).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (854).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1832).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2934).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (569).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (338).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2899).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2683).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2032).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1836).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (979).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (895).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1390).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (900).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1791).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1981).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1703).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2675).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1260).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1520).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2511).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1301).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (327).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (334).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1225).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1744).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (744).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (886).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2611).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (225).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1908).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2781).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1885).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (347).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1542).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2183).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1321).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (595).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2296).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (640).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2437).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2086).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (970).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1716).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2390).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1222).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2928).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (868).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1937).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (657).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2271).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (352).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1046).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2585).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (824).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1058).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2630).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1140).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (638).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2031).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1203).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1778).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1659).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (166).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1285).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2553).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2863).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (564).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2262).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2632).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2923).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2051).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2815).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (19).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2587).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2125).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2253).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2042).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2554).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2234).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (676).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1658).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2202).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1876).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (360).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2000).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2947).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (936).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1911).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2664).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1386).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2444).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1985).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1145).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (626).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2291).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (318).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1929).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2233).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1042).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2040).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (874).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (200).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1298).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1947).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2869).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (3).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1920).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2304).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (870).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (47).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2382).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2631).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (929).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (762).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (2181).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1231).jpg
#   inflating: /content/balanced_dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (635).jpg

# %%
# !pip install pywavelets
# Out:
# Requirement already satisfied: pywavelets in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from pywavelets) (1.26.4)

# %%
def load_and_preprocess_image(image_path, wavelet='db4', image_size=(512,512)):
    if not os.path.exists(image_path):
        raise ValueError(f"Image not found: {image_path}")

    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Image could not be loaded: {image_path}")

    img_resized = cv2.resize(img, image_size) / 255.0

    coeffs2 = pywt.dwt2(img_resized, wavelet)

    if coeffs2 is None or len(coeffs2) != 2:
        raise ValueError("Wavelet transformation failed to produce coefficients.")

    LL, (LH, HL, HH) = coeffs2

    LL = cv2.resize(LL, image_size)
    LH = cv2.resize(LH, image_size)
    HL = cv2.resize(HL, image_size)
    HH = cv2.resize(HH, image_size)

    wavelet_image = np.stack([LL, LH, HL, HH], axis=-1)

    return img_resized, wavelet_image


image_path = "/content/balanced_dataset/Normal/Normal (1010).jpg"
original_image, preprocessed_image = load_and_preprocess_image(image_path)

# Add a batch dimension for model prediction
preprocessed_image_batch = np.expand_dims(preprocessed_image, axis=0)

print(f"Preprocessed image shape: {preprocessed_image_batch.shape}")

# Make prediction
predicted_mask = model.predict(preprocessed_image_batch)

# Ensure the predicted mask is binary
predicted_mask_binary = (predicted_mask > 0.5).astype(np.uint8)

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].imshow(original_image, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')


axes[1].imshow(predicted_mask_binary[0, :, :, 0], cmap='gray')
axes[1].set_title('Predicted Mask')
axes[1].axis('off')

plt.tight_layout()
plt.show()

# Calculate and print metrics
predicted_flat = predicted_mask_binary[0, :, :, 0].flatten()
# Out:
# Preprocessed image shape: (1, 512, 512, 4)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
