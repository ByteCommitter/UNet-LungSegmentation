# %%
# !pip install -q kaggle

# %%
# !mkdir ~/.kaggle

# %%
# !mv /content/kaggle.json ~/.kaggle/
# Out:
# mv: cannot stat '/content/kaggle.json': No such file or directory

# %%
# start the download
# !kaggle datasets download 'artyomkolas/3-kinds-of-pneumonia'
# Out:
# Dataset URL: https://www.kaggle.com/datasets/artyomkolas/3-kinds-of-pneumonia
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading 3-kinds-of-pneumonia.zip to /content
#  99% 3.47G/3.49G [00:34<00:00, 184MB/s]
# 100% 3.49G/3.49G [00:34<00:00, 109MB/s]

# %%
# !unzip 3-kinds-of-pneumonia.zip -d dataset/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (691).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (692).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (693).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (694).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (695).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (696).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (697).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (698).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (699).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (7).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (70).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (700).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (701).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (702).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (703).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (704).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (705).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (706).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (707).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (708).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (709).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (71).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (710).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (711).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (712).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (713).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (714).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (715).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (716).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (717).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (718).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (719).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (72).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (720).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (721).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (722).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (723).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (724).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (725).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (726).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (727).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (728).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (729).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (73).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (730).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (731).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (732).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (733).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (734).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (735).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (736).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (737).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (738).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (739).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (74).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (740).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (741).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (742).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (743).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (744).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (745).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (746).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (747).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (748).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (749).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (75).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (750).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (751).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (752).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (753).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (754).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (755).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (756).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (757).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (758).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (759).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (76).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (760).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (761).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (762).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (763).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (764).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (765).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (766).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (767).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (768).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (769).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (77).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (770).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (771).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (772).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (773).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (774).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (775).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (776).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (777).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (778).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (779).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (78).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (780).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (781).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (782).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (783).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (784).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (785).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (786).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (787).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (788).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (789).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (79).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (790).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (791).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (792).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (793).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (794).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (795).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (796).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (797).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (798).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (799).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (8).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (80).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (800).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (801).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (802).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (803).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (804).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (805).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (806).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (807).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (808).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (809).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (81).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (810).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (811).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (812).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (813).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (814).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (815).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (816).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (817).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (818).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (819).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (82).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (820).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (821).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (822).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (823).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (824).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (825).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (826).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (827).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (828).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (829).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (83).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (830).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (831).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (832).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (833).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (834).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (835).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (836).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (837).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (838).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (839).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (84).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (840).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (841).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (842).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (843).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (844).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (845).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (846).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (847).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (848).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (849).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (85).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (850).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (851).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (852).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (853).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (854).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (855).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (856).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (857).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (858).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (859).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (86).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (860).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (861).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (862).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (863).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (864).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (865).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (866).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (867).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (868).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (869).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (87).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (870).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (871).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (872).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (873).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (874).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (875).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (876).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (877).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (878).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (879).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (88).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (880).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (881).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (882).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (883).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (884).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (885).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (886).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (887).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (888).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (889).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (89).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (890).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (891).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (892).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (893).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (894).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (895).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (896).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (897).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (898).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (899).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (9).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (90).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (900).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (901).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (902).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (903).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (904).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (905).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (906).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (907).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (908).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (909).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (91).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (910).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (911).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (912).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (913).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (914).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (915).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (916).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (917).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (918).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (919).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (92).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (920).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (921).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (922).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (923).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (924).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (925).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (926).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (927).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (928).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (929).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (93).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (930).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (931).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (932).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (933).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (934).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (935).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (936).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (937).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (938).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (939).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (94).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (940).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (941).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (942).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (943).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (944).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (945).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (946).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (947).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (948).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (949).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (95).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (950).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (951).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (952).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (953).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (954).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (955).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (956).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (957).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (958).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (959).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (96).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (960).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (961).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (962).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (963).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (964).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (965).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (966).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (967).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (968).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (969).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (97).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (970).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (971).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (972).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (973).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (974).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (975).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (976).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (977).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (978).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (979).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (98).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (980).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (981).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (982).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (983).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (984).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (985).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (986).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (987).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (988).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (989).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (99).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (990).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (991).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (992).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (993).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (994).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (995).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (996).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (997).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (998).jpg
#   inflating: dataset/Curated X-Ray Dataset/Normal/Normal (999).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (10).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (100).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1000).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1001).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1002).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1003).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1004).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1005).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1006).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1007).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1008).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1009).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (101).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1010).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1011).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1012).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1013).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1014).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1015).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1016).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1017).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1018).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1019).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (102).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1020).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1021).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1022).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1023).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1024).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1025).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1026).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1027).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1028).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1029).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (103).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1030).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1031).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1032).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1033).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1034).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1035).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1036).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1037).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1038).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1039).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (104).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1040).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1041).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1042).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1043).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1044).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1045).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1046).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1047).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1048).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1049).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (105).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1050).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1051).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1052).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1053).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1054).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1055).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1056).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1057).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1058).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1059).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (106).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1060).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1061).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1062).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1063).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1064).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1065).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1066).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1067).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1068).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1069).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (107).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1070).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1071).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1072).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1073).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1074).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1075).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1076).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1077).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1078).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1079).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (108).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1080).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1081).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1082).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1083).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1084).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1085).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1086).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1087).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1088).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1089).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (109).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1090).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1091).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1092).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1093).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1094).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1095).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1096).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1097).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1098).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1099).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (11).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (110).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1100).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1101).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1102).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1103).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1104).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1105).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1106).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1107).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1108).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1109).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (111).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1110).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1111).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1112).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1113).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1114).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1115).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1116).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1117).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1118).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1119).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (112).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1120).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1121).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1122).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1123).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1124).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1125).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1126).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1127).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1128).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1129).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (113).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1130).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1131).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1132).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1133).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1134).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1135).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1136).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1137).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1138).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1139).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (114).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1140).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1141).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1142).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1143).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1144).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1145).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1146).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1147).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1148).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1149).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (115).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1150).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1151).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1152).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1153).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1154).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1155).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1156).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1157).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1158).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1159).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (116).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1160).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1161).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1162).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1163).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1164).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1165).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1166).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1167).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1168).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1169).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (117).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1170).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1171).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1172).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1173).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1174).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1175).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1176).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1177).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1178).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1179).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (118).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1180).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1181).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1182).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1183).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1184).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1185).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1186).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1187).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1188).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1189).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (119).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1190).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1191).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1192).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1193).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1194).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1195).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1196).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1197).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1198).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1199).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (12).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (120).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1200).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1201).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1202).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1203).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1204).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1205).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1206).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1207).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1208).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1209).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (121).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1210).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1211).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1212).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1213).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1214).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1215).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1216).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1217).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1218).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1219).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (122).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1220).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1221).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1222).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1223).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1224).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1225).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Bacterial/Pneumonia-Bacterial (1226).jpg
# ...
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (833).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (834).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (835).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (836).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (837).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (838).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (839).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (84).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (840).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (841).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (842).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (843).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (844).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (845).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (846).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (847).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (848).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (849).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (85).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (850).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (851).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (852).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (853).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (854).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (855).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (856).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (857).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (858).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (859).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (86).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (860).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (861).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (862).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (863).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (864).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (865).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (866).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (867).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (868).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (869).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (87).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (870).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (871).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (872).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (873).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (874).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (875).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (876).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (877).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (878).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (879).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (88).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (880).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (881).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (882).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (883).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (884).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (885).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (886).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (887).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (888).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (889).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (89).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (890).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (891).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (892).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (893).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (894).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (895).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (896).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (897).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (898).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (899).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (9).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (90).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (900).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (901).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (902).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (903).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (904).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (905).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (906).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (907).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (908).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (909).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (91).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (910).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (911).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (912).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (913).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (914).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (915).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (916).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (917).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (918).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (919).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (92).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (920).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (921).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (922).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (923).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (924).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (925).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (926).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (927).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (928).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (929).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (93).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (930).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (931).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (932).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (933).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (934).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (935).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (936).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (937).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (938).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (939).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (94).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (940).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (941).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (942).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (943).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (944).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (945).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (946).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (947).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (948).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (949).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (95).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (950).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (951).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (952).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (953).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (954).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (955).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (956).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (957).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (958).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (959).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (96).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (960).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (961).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (962).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (963).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (964).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (965).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (966).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (967).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (968).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (969).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (97).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (970).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (971).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (972).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (973).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (974).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (975).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (976).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (977).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (978).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (979).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (98).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (980).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (981).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (982).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (983).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (984).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (985).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (986).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (987).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (988).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (989).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (99).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (990).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (991).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (992).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (993).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (994).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (995).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (996).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (997).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (998).jpg
#   inflating: dataset/Curated X-Ray Dataset/Pneumonia-Viral/Pneumonia-Viral (999).jpg

# %%
import os
import random
import shutil
from pathlib import Path
import zipfile

def create_balanced_dataset(source_path, target_path, n_samples=1656):
    """
    Create a balanced dataset by sampling equal numbers of images from each relevant directory.

    Args:
        source_path (str): Path to the main directory containing subdirectories
        target_path (str): Path where the balanced dataset will be created
        n_samples (int): Number of images to sample from each directory
    """
    # Create target directory if it doesn't exist
    os.makedirs(target_path, exist_ok=True)

    # Explicitly specify the directories we want to process
    desired_dirs = ['Normal', 'Pneumonia-Bacterial', 'Pneumonia-Viral']

    print("Starting to process directories...")

    for subdir in desired_dirs:
        print(f"\nProcessing {subdir}...")

        # Create corresponding directory in target path
        subdir_target = os.path.join(target_path, subdir)
        os.makedirs(subdir_target, exist_ok=True)

        # Get list of all images in the source subdirectory
        source_dir = os.path.join(source_path, subdir)

        # Check if directory exists
        if not os.path.exists(source_dir):
            print(f"Warning: Directory {subdir} not found at {source_dir}")
            continue

        all_images = [f for f in os.listdir(source_dir)
                     if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        print(f"Found {len(all_images)} images in {subdir}")

        if len(all_images) < n_samples:
            print(f"Warning: Directory {subdir} has fewer images ({len(all_images)}) than requested ({n_samples})")

        # Randomly sample n_samples images
        selected_images = random.sample(all_images, min(n_samples, len(all_images)))

        # Copy selected images to target directory
        successful_copies = 0
        for img in selected_images:
            try:
                shutil.copy2(
                    os.path.join(source_dir, img),
                    os.path.join(subdir_target, img)
                )
                successful_copies += 1
            except Exception as e:
                print(f"Error copying {img}: {str(e)}")

        print(f"Successfully copied {successful_copies} images from {subdir}")

def create_zip_file(source_dir, zip_name="balanced_dataset.zip"):
    """
    Create a zip file from the balanced dataset directory.
    """
    if not os.path.exists(source_dir):
        print(f"Error: Directory {source_dir} does not exist!")
        return

    with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
        file_count = 0
        for root, _, files in os.walk(source_dir):
            for file in files:
                file_path = os.path.join(root, file)
                arcname = os.path.relpath(file_path, source_dir)
                zipf.write(file_path, arcname)
                file_count += 1

    zip_size = os.path.getsize(zip_name) / (1024 * 1024)  # Convert to MB
    print(f"\nCreated zip file: {zip_name}")
    print(f"Total files in zip: {file_count}")
    print(f"Zip file size: {zip_size:.2f} MB")

# Example usage
source_path = "/content/dataset/Curated X-Ray Dataset/"
target_path = "/content/balanced_dataset"
final_zip = "balanced_dataset.zip"

print("Starting the process...")
print(f"Source path: {source_path}")
print(f"Target path: {target_path}")

# Create balanced dataset
create_balanced_dataset(source_path, target_path)

# Create zip file
create_zip_file(target_path, final_zip)
# Out:
# Starting the process...
# Source path: /content/dataset/Curated X-Ray Dataset/
# Target path: /content/balanced_dataset
# Starting to process directories...
#
# Processing Normal...
# Found 3270 images in Normal
# Successfully copied 1656 images from Normal
#
# Processing Pneumonia-Bacterial...
# Found 3001 images in Pneumonia-Bacterial
# Successfully copied 1656 images from Pneumonia-Bacterial
#
# Processing Pneumonia-Viral...
# Found 1656 images in Pneumonia-Viral
# Successfully copied 1656 images from Pneumonia-Viral
#
# Created zip file: balanced_dataset.zip
# Total files in zip: 4968
# Zip file size: 1646.35 MB

# %%
import os
import random
import shutil
import zipfile

# Paths to the original dataset directories
dir1_path = "/content/dataset/Curated X-Ray Dataset/Normal"
dir2_path = "/content/dataset/Curated X-Ray Dataset/Pneumonia-Bacterial"  # Pneumonia type 1
dir3_path = "/content/dataset/Curated X-Ray Dataset/Pneumonia-Viral"  # Pneumonia type 2

balanced_dataset_path = "/content/"
os.makedirs(balanced_dataset_path, exist_ok=True)

# Number of images required in each category
target_num_images = 1656

# Set a random seed for reproducibility
random.seed(42)

# Function to select images and copy them to the new directory
def select_and_copy_images(source_dir, target_dir, num_images):
    # Get all image filenames
    image_files = os.listdir(source_dir)

    # Select num_images randomly if more than required
    if len(image_files) > num_images:
        image_files = random.sample(image_files, num_images)

    # Create the target sub-directory
    os.makedirs(target_dir, exist_ok=True)

    # Copy selected images to target directory
    for image_file in image_files:
        shutil.copy(os.path.join(source_dir, image_file), target_dir)

# Select and copy images from each category
select_and_copy_images(dir1_path, os.path.join(balanced_dataset_path, "Normal"), target_num_images)
select_and_copy_images(dir2_path, os.path.join(balanced_dataset_path, "Pneumonia_Type1"), target_num_images)
select_and_copy_images(dir3_path, os.path.join(balanced_dataset_path, "Pneumonia_Type2"), target_num_images)

# Create zip file without compression
zip_path = "/content/balanced_dataset.zip"
with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_STORED) as zipf:
    for root, _, files in os.walk(balanced_dataset_path):
        for file in files:
            file_path = os.path.join(root, file)
            zipf.write(file_path, os.path.relpath(file_path, balanced_dataset_path))
            print(f"Added {file_path} to zip.")  # Optional: Progress update

# Clear the balanced dataset directory if needed to free up space
shutil.rmtree(balanced_dataset_path)  # Uncomment if you want to delete the temporary files

print("Balanced dataset created and zipped successfully at:", zip_path)
# Out:
# Added /content/3-kinds-of-pneumonia.zip to zip.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ff9cccd94580> in <cell line: 43>()
#      45         for file in files:
#      46             file_path = os.path.join(root, file)
# ---> 47             zipf.write(file_path, os.path.relpath(file_path, balanced_dataset_path))
#      48             print(f"Added {file_path} to zip.")  # Optional: Progress update
#      49
#
# /usr/lib/python3.10/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1787         else:
#    1788             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1789                 shutil.copyfileobj(src, dest, 1024*8)
#    1790
#    1791     def writestr(self, zinfo_or_arcname, data,
#
# /usr/lib/python3.10/shutil.py in copyfileobj(fsrc, fdst, length)
#     193     fdst_write = fdst.write
#     194     while True:
# --> 195         buf = fsrc_read(length)
#     196         if not buf:
#     197             break
#
# KeyboardInterrupt:

# %%
#download the zipped file from here
from google.colab import files
files.download('/content/balanced_dataset.zip')
