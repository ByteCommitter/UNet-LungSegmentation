jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (908).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2960).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2016).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (473).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1809).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1374).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (376).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2463).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1510).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1307).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2856).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (153).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2869).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (403).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (371).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1634).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2118).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2209).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1862).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2528).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1484).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1418).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1790).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2852).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1278).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (269).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1376).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (900).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1349).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (701).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (1154).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (615).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2130).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (64).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (173).jpg
#   inflating: /content/split_roi_dataset/val/Pneumonia-Bacterial/Pneumonia-Bacterial (2370).jpg

# %%
from tensorflow.keras.applications import EfficientNetB0

def create_model():
    # Load EfficientNetB0 with pretrained weights
    base_model = EfficientNetB0(
        weights='imagenet',
        include_top=False,
        input_shape=(224, 224, 3)
    )

    # Unfreeze layers for fine-tuning
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    x = base_model.output
    x = GlobalAveragePooling2D()(x)

    # Dense layers
    x = Dense(1024, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    predictions = Dense(3, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

def setup_data_generators():
    train_datagen = ImageDataGenerator(
        rescale=1.0/255,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        zoom_range=0.15,
        brightness_range=[0.8,1.2],
        fill_mode='nearest'
    )

    val_test_datagen = ImageDataGenerator(rescale=1.0/255)

    # Use the same paths for both normal and pywaveletted
    train_dir = '/content/split_roi_dataset/train'
    val_dir = '/content/split_roi_dataset/val'
    test_dir = '/content/split_roi_dataset/test'

    train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical'
    )

    validation_generator = val_test_datagen.flow_from_directory(
        val_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical'
    )

    test_generator = val_test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical'
    )

    return train_generator, validation_generator, test_generator

def train_model(model, train_generator, validation_generator):
    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        ModelCheckpoint(
            'best_resnet50_model.keras',
            monitor='val_accuracy',
            save_best_only=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=10,
            min_lr=1e-7,
            verbose=1
        )
    ]

    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=100,
        callbacks=callbacks,
        verbose=1
    )

    return history

def evaluate_model(model, test_generator):
    test_generator.reset()
    predictions = model.predict(test_generator)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_generator.classes
    class_labels = list(test_generator.class_indices.keys())

    from sklearn.metrics import classification_report, confusion_matrix
    import seaborn as sns

    # Confusion Matrix
    conf_matrix = confusion_matrix(true_classes, predicted_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(
        conf_matrix,
        annot=True,
        fmt='d',
        cmap='Blues',
        xticklabels=class_labels,
        yticklabels=class_labels
    )
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

    # Classification Report
    print("\nClassification Report:")
    print(classification_report(
        true_classes,
        predicted_classes,
        target_names=class_labels
    ))

# %%
# Create and run everything
model = create_model()
train_generator, validation_generator, test_generator = setup_data_generators()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Found 3969 images belonging to 3 classes.
# Found 495 images belonging to 3 classes.
# Found 499 images belonging to 3 classes.

# %%
history = train_model(model, train_generator, validation_generator)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 745ms/step - accuracy: 0.4631 - loss: 1.5160
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 194s 870ms/step - accuracy: 0.4634 - loss: 1.5152 - val_accuracy: 0.3333 - val_loss: 1.1012 - learning_rate: 1.0000e-04
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.5543 - loss: 1.2105
# Epoch 2: val_accuracy did not improve from 0.33333
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 100s 454ms/step - accuracy: 0.5543 - loss: 1.2104 - val_accuracy: 0.3333 - val_loss: 1.1062 - learning_rate: 1.0000e-04
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.5646 - loss: 1.1455
# Epoch 3: val_accuracy improved from 0.33333 to 0.36162, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 459ms/step - accuracy: 0.5647 - loss: 1.1453 - val_accuracy: 0.3616 - val_loss: 1.2807 - learning_rate: 1.0000e-04
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.6121 - loss: 1.0075
# Epoch 4: val_accuracy improved from 0.36162 to 0.37172, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 454ms/step - accuracy: 0.6121 - loss: 1.0074 - val_accuracy: 0.3717 - val_loss: 1.6781 - learning_rate: 1.0000e-04
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.6535 - loss: 0.9194
# Epoch 5: val_accuracy did not improve from 0.37172
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 453ms/step - accuracy: 0.6535 - loss: 0.9194 - val_accuracy: 0.3657 - val_loss: 1.7874 - learning_rate: 1.0000e-04
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.6510 - loss: 0.8845
# Epoch 6: val_accuracy improved from 0.37172 to 0.51515, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 83s 458ms/step - accuracy: 0.6510 - loss: 0.8845 - val_accuracy: 0.5152 - val_loss: 0.9888 - learning_rate: 1.0000e-04
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.6598 - loss: 0.8394
# Epoch 7: val_accuracy improved from 0.51515 to 0.64444, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 456ms/step - accuracy: 0.6599 - loss: 0.8393 - val_accuracy: 0.6444 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.6597 - loss: 0.7885
# Epoch 8: val_accuracy did not improve from 0.64444
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 445ms/step - accuracy: 0.6597 - loss: 0.7884 - val_accuracy: 0.6061 - val_loss: 0.9794 - learning_rate: 1.0000e-04
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.6857 - loss: 0.7390
# Epoch 9: val_accuracy improved from 0.64444 to 0.68081, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 459ms/step - accuracy: 0.6856 - loss: 0.7391 - val_accuracy: 0.6808 - val_loss: 0.7924 - learning_rate: 1.0000e-04
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.6923 - loss: 0.7404
# Epoch 10: val_accuracy improved from 0.68081 to 0.69697, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 454ms/step - accuracy: 0.6921 - loss: 0.7406 - val_accuracy: 0.6970 - val_loss: 0.6727 - learning_rate: 1.0000e-04
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.6936 - loss: 0.6991
# Epoch 11: val_accuracy improved from 0.69697 to 0.71919, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 61s 452ms/step - accuracy: 0.6936 - loss: 0.6991 - val_accuracy: 0.7192 - val_loss: 0.6947 - learning_rate: 1.0000e-04
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.7007 - loss: 0.6904
# Epoch 12: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 452ms/step - accuracy: 0.7007 - loss: 0.6903 - val_accuracy: 0.6808 - val_loss: 0.6211 - learning_rate: 1.0000e-04
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.7058 - loss: 0.6400
# Epoch 13: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 455ms/step - accuracy: 0.7058 - loss: 0.6402 - val_accuracy: 0.7131 - val_loss: 0.6461 - learning_rate: 1.0000e-04
# Epoch 14/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7079 - loss: 0.6533
# Epoch 14: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 446ms/step - accuracy: 0.7079 - loss: 0.6533 - val_accuracy: 0.7152 - val_loss: 0.6048 - learning_rate: 1.0000e-04
# Epoch 15/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7236 - loss: 0.6170
# Epoch 15: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 83s 449ms/step - accuracy: 0.7236 - loss: 0.6171 - val_accuracy: 0.6505 - val_loss: 0.7967 - learning_rate: 1.0000e-04
# Epoch 16/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7089 - loss: 0.6477
# Epoch 16: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 80s 443ms/step - accuracy: 0.7090 - loss: 0.6476 - val_accuracy: 0.7131 - val_loss: 0.6064 - learning_rate: 1.0000e-04
# Epoch 17/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.7287 - loss: 0.6052
# Epoch 17: val_accuracy did not improve from 0.71919
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 445ms/step - accuracy: 0.7287 - loss: 0.6053 - val_accuracy: 0.6747 - val_loss: 0.6742 - learning_rate: 1.0000e-04
# Epoch 18/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.7388 - loss: 0.5897
# Epoch 18: val_accuracy improved from 0.71919 to 0.73333, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 453ms/step - accuracy: 0.7387 - loss: 0.5897 - val_accuracy: 0.7333 - val_loss: 0.5760 - learning_rate: 1.0000e-04
# Epoch 19/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.7203 - loss: 0.6077
# Epoch 19: val_accuracy improved from 0.73333 to 0.73535, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 61s 456ms/step - accuracy: 0.7204 - loss: 0.6076 - val_accuracy: 0.7354 - val_loss: 0.5889 - learning_rate: 1.0000e-04
# Epoch 20/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.7424 - loss: 0.5515
# Epoch 20: val_accuracy did not improve from 0.73535
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 452ms/step - accuracy: 0.7425 - loss: 0.5516 - val_accuracy: 0.7253 - val_loss: 0.5790 - learning_rate: 1.0000e-04
# Epoch 21/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - accuracy: 0.7511 - loss: 0.5576
# Epoch 21: val_accuracy did not improve from 0.73535
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 67s 514ms/step - accuracy: 0.7510 - loss: 0.5576 - val_accuracy: 0.6545 - val_loss: 0.7324 - learning_rate: 1.0000e-04
# Epoch 22/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.7528 - loss: 0.5598
# Epoch 22: val_accuracy improved from 0.73535 to 0.74141, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 90s 571ms/step - accuracy: 0.7528 - loss: 0.5599 - val_accuracy: 0.7414 - val_loss: 0.6198 - learning_rate: 1.0000e-04
# Epoch 23/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7489 - loss: 0.5322
# Epoch 23: val_accuracy did not improve from 0.74141
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 66s 446ms/step - accuracy: 0.7489 - loss: 0.5322 - val_accuracy: 0.7152 - val_loss: 0.5802 - learning_rate: 1.0000e-04
# Epoch 24/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7506 - loss: 0.5553
# Epoch 24: val_accuracy did not improve from 0.74141
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 449ms/step - accuracy: 0.7506 - loss: 0.5552 - val_accuracy: 0.7152 - val_loss: 0.6185 - learning_rate: 1.0000e-04
# Epoch 25/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.7590 - loss: 0.5334
# Epoch 25: val_accuracy did not improve from 0.74141
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 450ms/step - accuracy: 0.7590 - loss: 0.5333 - val_accuracy: 0.7232 - val_loss: 0.6524 - learning_rate: 1.0000e-04
# Epoch 26/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7770 - loss: 0.4976
# Epoch 26: val_accuracy improved from 0.74141 to 0.75758, saving model to best_resnet50_model.keras
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 462ms/step - accuracy: 0.7770 - loss: 0.4976 - val_accuracy: 0.7576 - val_loss: 0.5563 - learning_rate: 1.0000e-04
# Epoch 27/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.7804 - loss: 0.4738
# Epoch 27: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 447ms/step - accuracy: 0.7804 - loss: 0.4739 - val_accuracy: 0.7414 - val_loss: 0.5958 - learning_rate: 1.0000e-04
# Epoch 28/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7916 - loss: 0.4890
# Epoch 28: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 452ms/step - accuracy: 0.7915 - loss: 0.4890 - val_accuracy: 0.7212 - val_loss: 0.5924 - learning_rate: 1.0000e-04
# Epoch 29/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.7892 - loss: 0.4873
# Epoch 29: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 449ms/step - accuracy: 0.7892 - loss: 0.4873 - val_accuracy: 0.7273 - val_loss: 0.6164 - learning_rate: 1.0000e-04
# Epoch 30/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7956 - loss: 0.4726
# Epoch 30: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 448ms/step - accuracy: 0.7956 - loss: 0.4727 - val_accuracy: 0.6545 - val_loss: 0.8150 - learning_rate: 1.0000e-04
# Epoch 31/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.7810 - loss: 0.4801
# Epoch 31: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 60s 449ms/step - accuracy: 0.7811 - loss: 0.4800 - val_accuracy: 0.6545 - val_loss: 0.8167 - learning_rate: 1.0000e-04
# Epoch 32/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8132 - loss: 0.4403
# Epoch 32: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 82s 449ms/step - accuracy: 0.8131 - loss: 0.4404 - val_accuracy: 0.6808 - val_loss: 0.7035 - learning_rate: 1.0000e-04
# Epoch 33/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.8088 - loss: 0.4516
# Epoch 33: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 452ms/step - accuracy: 0.8087 - loss: 0.4515 - val_accuracy: 0.7293 - val_loss: 0.5941 - learning_rate: 1.0000e-04
# Epoch 34/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.8241 - loss: 0.4277
# Epoch 34: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 81s 448ms/step - accuracy: 0.8240 - loss: 0.4279 - val_accuracy: 0.7333 - val_loss: 0.6235 - learning_rate: 1.0000e-04
# Epoch 35/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.8191 - loss: 0.4132
# Epoch 35: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 450ms/step - accuracy: 0.8191 - loss: 0.4132 - val_accuracy: 0.7172 - val_loss: 0.6764 - learning_rate: 1.0000e-04
# Epoch 36/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.8306 - loss: 0.4171
# Epoch 36: val_accuracy did not improve from 0.75758
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 83s 451ms/step - accuracy: 0.8306 - loss: 0.4171 - val_accuracy: 0.7333 - val_loss: 0.5636 - learning_rate: 1.0000e-04
# Epoch 37/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.8234 - loss: 0.4035
# Epoch 37: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 58s 446ms/step - accuracy: 0.8235 - loss: 0.4034 - val_accuracy: 0.7273 - val_loss: 0.6240 - learning_rate: 2.0000e-05
# Epoch 38/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8267 - loss: 0.3905
# Epoch 38: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 454ms/step - accuracy: 0.8268 - loss: 0.3904 - val_accuracy: 0.7273 - val_loss: 0.6138 - learning_rate: 2.0000e-05
# Epoch 39/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.8379 - loss: 0.3710
# Epoch 39: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 445ms/step - accuracy: 0.8378 - loss: 0.3712 - val_accuracy: 0.7293 - val_loss: 0.6267 - learning_rate: 2.0000e-05
# Epoch 40/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.8170 - loss: 0.4114
# Epoch 40: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 450ms/step - accuracy: 0.8171 - loss: 0.4112 - val_accuracy: 0.7051 - val_loss: 0.6561 - learning_rate: 2.0000e-05
# Epoch 41/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.8505 - loss: 0.3483
# Epoch 41: val_accuracy did not improve from 0.75758
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 59s 452ms/step - accuracy: 0.8504 - loss: 0.3484 - val_accuracy: 0.7131 - val_loss: 0.6723 - learning_rate: 2.0000e-05
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.

# %%
# Evaluate
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
evaluate_model(model, test_generator)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 493ms/step - accuracy: 0.7830 - loss: 0.5222
# Test accuracy: 77.76%
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 13s 510ms/step
# Classification Report:
#                      precision    recall  f1-score   support
#
#              Normal       0.36      0.35      0.35       167
# Pneumonia-Bacterial       0.36      0.34      0.35       166
#     Pneumonia-Viral       0.38      0.40      0.39       166
#
#            accuracy                           0.36       499
#           macro avg       0.36      0.36      0.36       499
#        weighted avg       0.36      0.36      0.36       499
